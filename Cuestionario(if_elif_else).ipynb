# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/cuestionario-if-elif-else-mariamorgado2-2/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %% [markdown]
# # Crea un celda de código debajo y escribe allí tu programa

# %%
print ("A jugar")

pregunta1 = input("¿Cuánto es 34 - 10?")
if int(pregunta1) == 24:
  print ("Es correcto")
else:
  print ("Es incorrecto")

pregunta2 = input("¿Cuántas peliculas tiene la saga de star wars?")
if int (pregunta2) == 9:
  print ("Es correcto")
else:
  print ("Es incorrecto")

pregunta3 = input ("""
¿Quién canta Black Horse and the Cherry Tree?
1 Kelly Clarkson
2 K.T. Tunstall
3 Hillary Duff
4 Bon Jovi""")

if int(pregunta3) == 2:
  print("Es correcto")
else:
  print("Es incorrecto")

pregunta4 = input("¿Cuánto es 3*2-1?")

if int(pregunta4) == 5:
  print("Es correcto")
else:
  print ("Es incorrecto")

pregunta5 = input("""¿Cuánto es la mitad de 300?
1 100
2 175
3 150""")

if int(pregunta5) == 3:
  print("Es correcto")
else:
  print("Es incorrecto")
# Out:
# A jugar
# ¿Cuánto es 34 - 10?24
# Es correcto
# ¿Cuántas peliculas tiene la saga de star wars?6
# Es incorrecto
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1 Kelly Clarkson
# 2 K.T. Tunstall
# 3 Hillary Duff
# 4 Bon Jovi2
# Es correcto
# ¿Cuánto es 3*2-1?5
# Es correcto
# ¿Cuánto es la mitad de 300?
# 1 100
# 2 175
# 3 1502
# Es incorrecto
